# %%
# !pip install roboflow
# Out:
# ...
#   Using cached roboflow-1.1.21-py3-none-any.whl (70 kB)
# ...
#   Using cached certifi-2023.7.22-py3-none-any.whl (158 kB)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.12 requires torch<2.1,>=1.7, but you have torch 2.2.0 which is incompatible.
# conda-repo-cli 1.0.27 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.27 requires nbformat==5.4.0, but you have nbformat 5.1.3 which is incompatible.
# conda-repo-cli 1.0.27 requires requests==2.28.1, but you have requests 2.28.2 which is incompatible.
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# ...
#   Using cached supervision-0.18.0-py3-none-any.whl (86 kB)
# ...
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# ...
#   Using cached opencv_python_headless-4.8.0.74-cp37-abi3-win_amd64.whl (38.0 MB)
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="VsyWKTPB44vZNxw587Lr")
project = rf.workspace("sut-vc5zi").project("poisonous-animals")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.1.15, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to poisonous-animals-1 in yolov8:: 100%|██████████| 3980/3980 [00:02<00:00, 1631.21it/s]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os, glob


# %matplotlib inline

# %%
os.listdir('./poisonous-animals-1')
# Out:
# ['data.yaml',
#  'README.dataset.txt',
#  'README.roboflow.txt',
#  'test',
#  'train',
#  'valid']

# %%
os.listdir('./poisonous-animals-1/train')
# Out:
# ['images', 'labels']

# %%
start = 0

for img_file in os.listdir('./poisonous-animals-1/train/images/'):
#     print(img_file.rstrip('.jpg'))
    os.rename('./poisonous-animals-1/train/images/' + img_file, f'./poisonous-animals-1/train/images/train_{start:04d}.jpg')
    os.rename('./poisonous-animals-1/train/labels/' + img_file.rstrip('.jpg') + '.txt', f'./poisonous-animals-1/train/labels/train_{start:04d}.txt')
    start+=1
# Out:
# train_000
# train_001
# train_002
# train_003
# train_004
# train_005
# train_006
# train_007
# train_008
# train_009
# train_010
# train_011
# train_012
# train_013
# train_014
# train_015
# train_016
# train_017
# train_018
# train_019
# train_020
# train_021
# train_022
# train_023
# train_024
# train_025
# train_026
# train_027
# train_028
# train_029
# train_030
# train_031
# train_032
# train_033
# train_034
# train_035
# train_036
# train_037
# train_038
# train_039
# train_040
# train_041
# train_042
# train_043
# train_044
# train_045
# train_046
# train_047
# train_048
# train_049
# train_050
# train_051
# train_052
# train_053
# train_054
# train_055
# train_056
# train_057
# train_058
# train_059
# train_060
# train_061
# train_062
# train_063
# train_064
# train_065
# train_066
# train_067
# train_068
# train_069
# train_070
# train_071
# train_072
# train_073
# train_074
# train_075
# train_076
# train_077
# train_078
# train_079
# train_080
# train_081
# train_082
# ...

# %%
start = 0

for img_file in os.listdir('./poisonous-animals-1/valid/images/'):
#     print(img_file.rstrip('.jpg'))
    os.rename('./poisonous-animals-1/valid/images/' + img_file, f'./poisonous-animals-1/valid/images/valid_{start:03d}.jpg')
    os.rename('./poisonous-animals-1/valid/labels/' + img_file.rstrip('.jpg') + '.txt', f'./poisonous-animals-1/valid/labels/valid_{start:03d}.txt')
    start+=1

# %%
start = 0

for img_file in os.listdir('./poisonous-animals-1/test/images/'):
#     print(img_file.rstrip('.jpg'))
    os.rename('./poisonous-animals-1/test/images/' + img_file, f'./poisonous-animals-1/test/images/test_{start:03d}.jpg')
    os.rename('./poisonous-animals-1/test/labels/' + img_file.rstrip('.jpg') + '.txt', f'./poisonous-animals-1/test/labels/test_{start:03d}.txt')
    start+=1
